# %%
# License: BSD
# Author: Sasank Chilamkurthy

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from PIL import Image
from tempfile import TemporaryDirectory
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import random_split

# %%
data_dir = "C:/Users/user/OneDrive/Masaüstü/RGB_malwareimages"

# Define transformations for your images (adjust as needed)
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(224),  # Resize for EfficientNet-B3
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Create the ImageFolder dataset
dataset = datasets.ImageFolder(root=data_dir, transform=train_transforms)

# Define the validation set split ratio (e.g., 20% for validation)
val_split = 0.2

# Split the dataset into train and validation sets using random_split
train_size = int(len(dataset) * (1 - val_split))
val_size = len(dataset) - train_size
train_data, val_data = random_split(dataset, [train_size, val_size])

image_datasets = {
    'train': train_data,
    'val': val_data,
}

dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = dataset.classes

# ... rest of your transfer learning code using train_loader and val_loader
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
#test-transform
test_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.ToTensor(), 
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
test_data = datasets.ImageFolder("C:/Users/user/OneDrive/Masaüstü/RGB_test", transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_data, batch_size = 16, num_workers = 0)

# %%
def imshow(inp, title=None):
    #Display image for Tensor
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
writer = SummaryWriter("C:/Users/user/parca_experiment_rgb_efficientnetb5_sgd_001")

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            
            if phase == "train":
                writer.add_scalar("Training Loss", epoch_loss, epoch)
                writer.add_scalar("Training Accuracy", epoch_acc, epoch)
            elif phase == 'val':
                writer.add_scalar("Validation Loss", epoch_loss, epoch)
                writer.add_scalar("Validation Accuracy", epoch_acc, epoch)
            

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')
    writer.close()
    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ft = models.efficientnet_b5(weights='IMAGENET1K_V1')
num_ftrs =  model_ft.classifier[1].in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model_ft.fc = nn.Linear(num_ftrs, 9)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.01, momentum=0.9) #0.01

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,num_epochs=120)
# Out:
# Epoch 0/119
# ----------
# train Loss: 1.2095 Acc: 0.6164
# val Loss: 0.7754 Acc: 0.7435
#
# Epoch 1/119
# ----------
# train Loss: 0.7542 Acc: 0.7453
# val Loss: 0.8555 Acc: 0.6895
#
# Epoch 2/119
# ----------
# train Loss: 0.6125 Acc: 0.8005
# val Loss: 0.6642 Acc: 0.7901
#
# Epoch 3/119
# ----------
# train Loss: 0.5325 Acc: 0.8251
# val Loss: 0.4127 Acc: 0.8752
#
# Epoch 4/119
# ----------
# train Loss: 0.4955 Acc: 0.8373
# val Loss: 0.3749 Acc: 0.8821
#
# Epoch 5/119
# ----------
# train Loss: 0.4389 Acc: 0.8563
# val Loss: 0.4708 Acc: 0.8591
#
# Epoch 6/119
# ----------
# train Loss: 0.3997 Acc: 0.8673
# val Loss: 0.4182 Acc: 0.8746
#
# Epoch 7/119
# ----------
# train Loss: 0.3163 Acc: 0.8950
# val Loss: 0.2979 Acc: 0.9143
#
# Epoch 8/119
# ----------
# train Loss: 0.2701 Acc: 0.9035
# val Loss: 0.2627 Acc: 0.9189
#
# Epoch 9/119
# ----------
# train Loss: 0.2653 Acc: 0.9082
# val Loss: 0.2519 Acc: 0.9252
#
# Epoch 10/119
# ----------
# train Loss: 0.2468 Acc: 0.9133
# val Loss: 0.2611 Acc: 0.9195
#
# Epoch 11/119
# ----------
# train Loss: 0.2454 Acc: 0.9137
# val Loss: 0.2549 Acc: 0.9212
#
# Epoch 12/119
# ----------
# train Loss: 0.2458 Acc: 0.9154
# val Loss: 0.2534 Acc: 0.9229
#
# Epoch 13/119
# ----------
# train Loss: 0.2299 Acc: 0.9210
# val Loss: 0.2508 Acc: 0.9206
#
# Epoch 14/119
# ----------
# train Loss: 0.2239 Acc: 0.9236
# val Loss: 0.2374 Acc: 0.9235
#
# Epoch 15/119
# ----------
# train Loss: 0.2190 Acc: 0.9256
# val Loss: 0.2355 Acc: 0.9287
#
# Epoch 16/119
# ----------
# train Loss: 0.2263 Acc: 0.9231
# val Loss: 0.2285 Acc: 0.9247
#
# Epoch 17/119
# ----------
# train Loss: 0.2379 Acc: 0.9156
# val Loss: 0.2284 Acc: 0.9287
#
# Epoch 18/119
# ----------
# train Loss: 0.2134 Acc: 0.9262
# val Loss: 0.1995 Acc: 0.9379
#
# Epoch 19/119
# ----------
# train Loss: 0.2183 Acc: 0.9248
# val Loss: 0.2430 Acc: 0.9264
#
# Epoch 20/119
# ----------
# train Loss: 0.2272 Acc: 0.9236
# val Loss: 0.2186 Acc: 0.9333
#
# Epoch 21/119
# ----------
# train Loss: 0.2105 Acc: 0.9267
# val Loss: 0.2491 Acc: 0.9252
#
# Epoch 22/119
# ----------
# train Loss: 0.2174 Acc: 0.9281
# val Loss: 0.2433 Acc: 0.9258
#
# Epoch 23/119
# ----------
# train Loss: 0.2087 Acc: 0.9285
# val Loss: 0.2303 Acc: 0.9344
#
# Epoch 24/119
# ----------
# train Loss: 0.2195 Acc: 0.9177
# val Loss: 0.2353 Acc: 0.9310
#
# Epoch 25/119
# ----------
# train Loss: 0.2143 Acc: 0.9277
# val Loss: 0.2401 Acc: 0.9327
#
# Epoch 26/119
# ----------
# train Loss: 0.2176 Acc: 0.9239
# val Loss: 0.2243 Acc: 0.9316
#
# Epoch 27/119
# ----------
# train Loss: 0.2122 Acc: 0.9278
# val Loss: 0.2251 Acc: 0.9287
#
# Epoch 28/119
# ----------
# train Loss: 0.2213 Acc: 0.9200
# val Loss: 0.2292 Acc: 0.9333
#
# Epoch 29/119
# ----------
# train Loss: 0.2118 Acc: 0.9271
# val Loss: 0.2299 Acc: 0.9402
#
# Epoch 30/119
# ----------
# train Loss: 0.2083 Acc: 0.9310
# val Loss: 0.2198 Acc: 0.9327
#
# Epoch 31/119
# ----------
# train Loss: 0.2141 Acc: 0.9285
# val Loss: 0.2322 Acc: 0.9287
#
# Epoch 32/119
# ----------
# train Loss: 0.2238 Acc: 0.9233
# val Loss: 0.2084 Acc: 0.9344
#
# Epoch 33/119
# ----------
# train Loss: 0.2182 Acc: 0.9245
# val Loss: 0.2325 Acc: 0.9275
#
# Epoch 34/119
# ----------
# train Loss: 0.2139 Acc: 0.9222
# val Loss: 0.2557 Acc: 0.9212
#
# Epoch 35/119
# ----------
# train Loss: 0.2186 Acc: 0.9235
# val Loss: 0.2560 Acc: 0.9235
#
# Epoch 36/119
# ----------
# train Loss: 0.2254 Acc: 0.9196
# val Loss: 0.2286 Acc: 0.9333
#
# Epoch 37/119
# ----------
# train Loss: 0.2184 Acc: 0.9218
# val Loss: 0.2432 Acc: 0.9235
#
# Epoch 38/119
# ----------
# train Loss: 0.2268 Acc: 0.9222
# val Loss: 0.2320 Acc: 0.9264
#
# Epoch 39/119
# ----------
# train Loss: 0.2092 Acc: 0.9255
# val Loss: 0.2093 Acc: 0.9396
#
# Epoch 40/119
# ----------
# train Loss: 0.2128 Acc: 0.9267
# val Loss: 0.2233 Acc: 0.9321
#
# Epoch 41/119
# ----------
# train Loss: 0.2205 Acc: 0.9236
# val Loss: 0.2397 Acc: 0.9316
#
# Epoch 42/119
# ----------
# train Loss: 0.2265 Acc: 0.9268
# val Loss: 0.2313 Acc: 0.9333
#
# Epoch 43/119
# ----------
# train Loss: 0.2061 Acc: 0.9284
# val Loss: 0.2107 Acc: 0.9390
#
# Epoch 44/119
# ----------
# train Loss: 0.2209 Acc: 0.9242
# val Loss: 0.2500 Acc: 0.9304
#
# Epoch 45/119
# ----------
# train Loss: 0.2036 Acc: 0.9318
# val Loss: 0.2280 Acc: 0.9229
#
# Epoch 46/119
# ----------
# train Loss: 0.2148 Acc: 0.9254
# val Loss: 0.2126 Acc: 0.9333
#
# Epoch 47/119
# ----------
# train Loss: 0.2154 Acc: 0.9218
# val Loss: 0.2372 Acc: 0.9316
#
# Epoch 48/119
# ----------
# train Loss: 0.2369 Acc: 0.9170
# val Loss: 0.2239 Acc: 0.9321
#
# Epoch 49/119
# ----------
# train Loss: 0.2207 Acc: 0.9210
# val Loss: 0.2308 Acc: 0.9229
#
# Epoch 50/119
# ----------
# train Loss: 0.2151 Acc: 0.9241
# val Loss: 0.2158 Acc: 0.9362
#
# Epoch 51/119
# ----------
# train Loss: 0.2204 Acc: 0.9252
# val Loss: 0.2402 Acc: 0.9252
#
# Epoch 52/119
# ----------
# train Loss: 0.2138 Acc: 0.9249
# val Loss: 0.2346 Acc: 0.9350
#
# Epoch 53/119
# ----------
# train Loss: 0.2090 Acc: 0.9302
# val Loss: 0.2305 Acc: 0.9258
#
# Epoch 54/119
# ----------
# train Loss: 0.2192 Acc: 0.9246
# val Loss: 0.2382 Acc: 0.9333
#
# Epoch 55/119
# ----------
# train Loss: 0.2162 Acc: 0.9229
# val Loss: 0.2187 Acc: 0.9344
#
# Epoch 56/119
# ----------
# train Loss: 0.2094 Acc: 0.9279
# val Loss: 0.2259 Acc: 0.9367
#
# Epoch 57/119
# ----------
# train Loss: 0.2084 Acc: 0.9291
# val Loss: 0.2228 Acc: 0.9316
#
# Epoch 58/119
# ----------
# train Loss: 0.2144 Acc: 0.9255
# val Loss: 0.2300 Acc: 0.9362
#
# Epoch 59/119
# ----------
# train Loss: 0.2141 Acc: 0.9256
# val Loss: 0.2500 Acc: 0.9270
#
# Epoch 60/119
# ----------
# train Loss: 0.2201 Acc: 0.9265
# val Loss: 0.2223 Acc: 0.9327
#
# Epoch 61/119
# ----------
# train Loss: 0.2129 Acc: 0.9290
# val Loss: 0.2215 Acc: 0.9247
#
# Epoch 62/119
# ----------
# train Loss: 0.2182 Acc: 0.9223
# val Loss: 0.2337 Acc: 0.9293
#
# Epoch 63/119
# ----------
# train Loss: 0.2156 Acc: 0.9243
# val Loss: 0.2191 Acc: 0.9350
#
# Epoch 64/119
# ----------
# train Loss: 0.2175 Acc: 0.9241
# val Loss: 0.2390 Acc: 0.9281
#
# Epoch 65/119
# ----------
# train Loss: 0.2240 Acc: 0.9219
# val Loss: 0.2452 Acc: 0.9264
#
# Epoch 66/119
# ----------
# train Loss: 0.2148 Acc: 0.9252
# val Loss: 0.2376 Acc: 0.9298
#
# Epoch 67/119
# ----------
# train Loss: 0.2164 Acc: 0.9274
# val Loss: 0.2365 Acc: 0.9321
#
# Epoch 68/119
# ----------
# train Loss: 0.2150 Acc: 0.9255
# val Loss: 0.2185 Acc: 0.9293
#
# Epoch 69/119
# ----------
# train Loss: 0.2123 Acc: 0.9269
# val Loss: 0.2558 Acc: 0.9287
#
# Epoch 70/119
# ----------
# train Loss: 0.2166 Acc: 0.9265
# val Loss: 0.2371 Acc: 0.9304
#
# Epoch 71/119
# ----------
# train Loss: 0.2144 Acc: 0.9252
# val Loss: 0.2218 Acc: 0.9310
#
# Epoch 72/119
# ----------
# train Loss: 0.2204 Acc: 0.9249
# val Loss: 0.2460 Acc: 0.9241
#
# Epoch 73/119
# ----------
# train Loss: 0.2235 Acc: 0.9245
# val Loss: 0.2314 Acc: 0.9327
#
# Epoch 74/119
# ----------
# train Loss: 0.2165 Acc: 0.9242
# val Loss: 0.2283 Acc: 0.9293
#
# Epoch 75/119
# ----------
# train Loss: 0.2129 Acc: 0.9238
# val Loss: 0.2217 Acc: 0.9344
#
# Epoch 76/119
# ----------
# train Loss: 0.2201 Acc: 0.9233
# val Loss: 0.2475 Acc: 0.9195
#
# Epoch 77/119
# ----------
# train Loss: 0.2184 Acc: 0.9249
# val Loss: 0.2333 Acc: 0.9275
#
# Epoch 78/119
# ----------
# train Loss: 0.2129 Acc: 0.9235
# val Loss: 0.2355 Acc: 0.9310
#
# Epoch 79/119
# ----------
# train Loss: 0.2237 Acc: 0.9225
# val Loss: 0.2351 Acc: 0.9344
#
# Epoch 80/119
# ----------
# train Loss: 0.2196 Acc: 0.9223
# val Loss: 0.2169 Acc: 0.9362
#
# Epoch 81/119
# ----------
# train Loss: 0.2216 Acc: 0.9231
# val Loss: 0.2418 Acc: 0.9327
#
# Epoch 82/119
# ----------
# train Loss: 0.2184 Acc: 0.9231
# val Loss: 0.2271 Acc: 0.9281
#
# Epoch 83/119
# ----------
# train Loss: 0.2148 Acc: 0.9271
# val Loss: 0.2136 Acc: 0.9298
#
# Epoch 84/119
# ----------
# train Loss: 0.2183 Acc: 0.9232
# val Loss: 0.2378 Acc: 0.9287
#
# Epoch 85/119
# ----------
# train Loss: 0.2169 Acc: 0.9265
# val Loss: 0.2188 Acc: 0.9327
#
# Epoch 86/119
# ----------
# train Loss: 0.2201 Acc: 0.9212
# val Loss: 0.2069 Acc: 0.9448
#
# Epoch 87/119
# ----------
# train Loss: 0.2139 Acc: 0.9279
# val Loss: 0.2417 Acc: 0.9339
#
# Epoch 88/119
# ----------
# train Loss: 0.2073 Acc: 0.9318
# val Loss: 0.2158 Acc: 0.9379
#
# Epoch 89/119
# ----------
# train Loss: 0.2166 Acc: 0.9219
# val Loss: 0.2350 Acc: 0.9304
#
# Epoch 90/119
# ----------
# train Loss: 0.2114 Acc: 0.9255
# val Loss: 0.2174 Acc: 0.9333
#
# Epoch 91/119
# ----------
# train Loss: 0.2192 Acc: 0.9232
# val Loss: 0.2481 Acc: 0.9229
#
# Epoch 92/119
# ----------
# train Loss: 0.2083 Acc: 0.9282
# val Loss: 0.2408 Acc: 0.9339
#
# Epoch 93/119
# ----------
# train Loss: 0.2246 Acc: 0.9225
# val Loss: 0.2079 Acc: 0.9362
#
# Epoch 94/119
# ----------
# train Loss: 0.2132 Acc: 0.9271
# val Loss: 0.2223 Acc: 0.9333
#
# Epoch 95/119
# ----------
# train Loss: 0.2097 Acc: 0.9249
# val Loss: 0.2389 Acc: 0.9183
#
# Epoch 96/119
# ----------
# train Loss: 0.2152 Acc: 0.9265
# val Loss: 0.2237 Acc: 0.9316
#
# Epoch 97/119
# ----------
# train Loss: 0.2166 Acc: 0.9262
# val Loss: 0.2200 Acc: 0.9339
#
# Epoch 98/119
# ----------
# train Loss: 0.2110 Acc: 0.9251
# val Loss: 0.2447 Acc: 0.9304
#
# Epoch 99/119
# ----------
# train Loss: 0.2213 Acc: 0.9242
# val Loss: 0.2187 Acc: 0.9316
#
# Epoch 100/119
# ----------
# train Loss: 0.2115 Acc: 0.9272
# val Loss: 0.2289 Acc: 0.9229
#
# Epoch 101/119
# ----------
# train Loss: 0.2149 Acc: 0.9282
# val Loss: 0.2231 Acc: 0.9333
#
# Epoch 102/119
# ----------
# train Loss: 0.2154 Acc: 0.9262
# val Loss: 0.2377 Acc: 0.9310
#
# Epoch 103/119
# ----------
# train Loss: 0.2132 Acc: 0.9256
# val Loss: 0.2230 Acc: 0.9316
#
# Epoch 104/119
# ----------
# train Loss: 0.2300 Acc: 0.9199
# val Loss: 0.2483 Acc: 0.9212
#
# Epoch 105/119
# ----------
# train Loss: 0.2165 Acc: 0.9256
# val Loss: 0.2277 Acc: 0.9367
#
# Epoch 106/119
# ----------
# train Loss: 0.2252 Acc: 0.9235
# val Loss: 0.2407 Acc: 0.9252
#
# Epoch 107/119
# ----------
# train Loss: 0.2077 Acc: 0.9282
# val Loss: 0.2413 Acc: 0.9224
#
# Epoch 108/119
# ----------
# train Loss: 0.2144 Acc: 0.9249
# val Loss: 0.2226 Acc: 0.9293
#
# Epoch 109/119
# ----------
# train Loss: 0.2250 Acc: 0.9243
# val Loss: 0.2040 Acc: 0.9367
#
# Epoch 110/119
# ----------
# train Loss: 0.2134 Acc: 0.9274
# val Loss: 0.2475 Acc: 0.9247
#
# Epoch 111/119
# ----------
# train Loss: 0.2255 Acc: 0.9236
# val Loss: 0.2193 Acc: 0.9316
#
# Epoch 112/119
# ----------
# train Loss: 0.2159 Acc: 0.9261
# val Loss: 0.2317 Acc: 0.9362
#
# Epoch 113/119
# ----------
# train Loss: 0.2006 Acc: 0.9317
# val Loss: 0.2286 Acc: 0.9293
#
# Epoch 114/119
# ----------
# train Loss: 0.2251 Acc: 0.9209
# val Loss: 0.2437 Acc: 0.9304
#
# Epoch 115/119
# ----------
# train Loss: 0.2177 Acc: 0.9222
# val Loss: 0.2389 Acc: 0.9270
#
# Epoch 116/119
# ----------
# train Loss: 0.2149 Acc: 0.9248
# val Loss: 0.2267 Acc: 0.9310
#
# Epoch 117/119
# ----------
# train Loss: 0.2136 Acc: 0.9285
# val Loss: 0.2306 Acc: 0.9258
#
# Epoch 118/119
# ----------
# train Loss: 0.2187 Acc: 0.9235
# val Loss: 0.2316 Acc: 0.9310
#
# Epoch 119/119
# ----------
# train Loss: 0.2188 Acc: 0.9245
# val Loss: 0.2482 Acc: 0.9218
#
# Training complete in 394m 19s
# Best val Acc: 0.944796

# %%
torch.save(model_ft.state_dict(), "C:/Users/user/Documents/experimentefficientnetb5001sgdrgb.pt")

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_model(model_ft)

# %%
correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        # calculate outputs by running images through the network
        outputs = model_ft(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of the network on the big15 test images: {100 * correct // total} %')
# Out:
# Accuracy of the network on the big15 test images: 91 %

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
predicted_labels = []
true_labels = []
label_names = ['Gatak', 'Kelihos_ver1', 'Kelihos_ver3', 'Lollipop', 'Obfuscator.ACY', 'Ramnit', 'Simda', 'Tracur', 'Vundo']
model_ft.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model_ft(images)
        _,predicted = torch.max(outputs, 1)
        predicted_labels.extend(predicted.cpu().numpy())
        true_labels.extend(labels.cpu().numpy())
predicted_labels = np.array(predicted_labels)
true_labels = np.array(true_labels)
confusion = confusion_matrix(true_labels, predicted_labels)
normalized_matrix = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
sns.set()
plt.figure(figsize=(10, 8))
sns.heatmap(normalized_matrix, annot=True, cmap="Blues", xticklabels=label_names, yticklabels=label_names)
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
# Out:
# Text(92.109375, 0.5, 'True labels')

# %%
model_ft.load_state_dict(torch.load("C:/Users/user/Documents/experimentefficientnetb5001sgdrgb.pt"))
# Out:
# <All keys matched successfully>

# %%
from sklearn.metrics import precision_score, recall_score, f1_score



# Set the model to evaluation mode
model_ft.eval()

# Initialize lists to hold true and predicted labels
true_labels = []
pred_labels = []

# Disable gradient calculation for evaluation
with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        outputs = model_ft(images)
        _, preds = torch.max(outputs, 1)
        true_labels.extend(labels.cpu().numpy())
        pred_labels.extend(preds.cpu().numpy())

# Calculate precision, recall, and F1-score
precision = precision_score(true_labels, pred_labels, average='macro')
recall = recall_score(true_labels, pred_labels, average='macro')
f1 = f1_score(true_labels, pred_labels, average='macro')

print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')
# Out:
# Precision: 0.8550
# Recall: 0.8777
# F1 Score: 0.8646

# %%
# Evaluate the model on test data and record metrics
def evaluate_test_data_plot(model, criterion):
    model.eval()
    test_losses = []
    test_accuracies = []

    running_loss = 0.0
    running_corrects = 0
    num_batches = 0

    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        with torch.no_grad():
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        num_batches += 1

        batch_loss = loss.item()
        batch_acc = torch.sum(preds == labels.data).double() / inputs.size(0)

        test_losses.append(batch_loss)
        test_accuracies.append(batch_acc.cpu().numpy())

    test_loss = running_loss / len(test_data)
    test_acc = running_corrects.double() / len(test_data)

    print(f'Test Loss: {test_loss:.4f} Acc: {test_acc:.4f}')

    return test_losses, test_accuracies


# Plot metrics
def plot_metrics(test_loss, test_acc):
    num_epochs = len(test_acc)

    # Plot test metrics
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.plot(range(num_epochs), test_loss, label='Test Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Test Loss')

    plt.subplot(1, 2, 2)
    plt.plot(range(num_epochs), test_acc, label='Test Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Test Accuracy')

    plt.show()
    plt.tight_layout()
    plt.show()

# %%
test_loss, test_acc = evaluate_test_data_plot(model_ft, criterion)
plot_metrics(test_loss, test_acc)
# Out:
# Test Loss: 0.2904 Acc: 0.9127

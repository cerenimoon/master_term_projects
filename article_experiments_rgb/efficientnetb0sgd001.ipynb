# %%
# License: BSD
# Author: Sasank Chilamkurthy

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from PIL import Image
from tempfile import TemporaryDirectory
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import random_split

# %%
data_dir = "C:/Users/user/OneDrive/Masaüstü/RGB_malwareimages"

# Define transformations for your images (adjust as needed)
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(224),  # Resize for EfficientNet-B3
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Create the ImageFolder dataset
dataset = datasets.ImageFolder(root=data_dir, transform=train_transforms)

# Define the validation set split ratio (e.g., 20% for validation)
val_split = 0.2

# Split the dataset into train and validation sets using random_split
train_size = int(len(dataset) * (1 - val_split))
val_size = len(dataset) - train_size
train_data, val_data = random_split(dataset, [train_size, val_size])

image_datasets = {
    'train': train_data,
    'val': val_data,
}

dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = dataset.classes

# ... rest of your transfer learning code using train_loader and val_loader
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
#test-transform
test_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.ToTensor(), 
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
test_data = datasets.ImageFolder("C:/Users/user/OneDrive/Masaüstü/RGB_test", transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_data, batch_size = 16, num_workers = 0)

# %%
def imshow(inp, title=None):
    #Display image for Tensor
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
writer = SummaryWriter("C:/Users/user/parca_experiment_rgb_efficientnetb0_sgd_001")

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            
            if phase == "train":
                writer.add_scalar("Training Loss", epoch_loss, epoch)
                writer.add_scalar("Training Accuracy", epoch_acc, epoch)
            elif phase == 'val':
                writer.add_scalar("Validation Loss", epoch_loss, epoch)
                writer.add_scalar("Validation Accuracy", epoch_acc, epoch)
            

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')
    writer.close()
    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ft = models.efficientnet_b0(weights='IMAGENET1K_V1')
num_ftrs =  model_ft.classifier[1].in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model_ft.fc = nn.Linear(num_ftrs, 9)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.01, momentum=0.9) #0.01

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,num_epochs=120)
# Out:
# Epoch 0/119
# ----------
# train Loss: 1.3287 Acc: 0.5828
# val Loss: 0.7666 Acc: 0.7585
#
# Epoch 1/119
# ----------
# train Loss: 0.8348 Acc: 0.7193
# val Loss: 0.6763 Acc: 0.7717
#
# Epoch 2/119
# ----------
# train Loss: 0.7196 Acc: 0.7605
# val Loss: 0.5104 Acc: 0.8315
#
# Epoch 3/119
# ----------
# train Loss: 0.6449 Acc: 0.7807
# val Loss: 0.5611 Acc: 0.8229
#
# Epoch 4/119
# ----------
# train Loss: 0.5742 Acc: 0.8089
# val Loss: 0.5383 Acc: 0.8183
#
# Epoch 5/119
# ----------
# train Loss: 0.5427 Acc: 0.8148
# val Loss: 0.4665 Acc: 0.8551
#
# Epoch 6/119
# ----------
# train Loss: 0.5165 Acc: 0.8247
# val Loss: 0.8067 Acc: 0.7809
#
# Epoch 7/119
# ----------
# train Loss: 0.4034 Acc: 0.8654
# val Loss: 0.3824 Acc: 0.8741
#
# Epoch 8/119
# ----------
# train Loss: 0.3526 Acc: 0.8813
# val Loss: 0.3464 Acc: 0.8936
#
# Epoch 9/119
# ----------
# train Loss: 0.3326 Acc: 0.8875
# val Loss: 0.3676 Acc: 0.8798
#
# Epoch 10/119
# ----------
# train Loss: 0.3257 Acc: 0.8881
# val Loss: 0.3660 Acc: 0.8930
#
# Epoch 11/119
# ----------
# train Loss: 0.3224 Acc: 0.8910
# val Loss: 0.3369 Acc: 0.8988
#
# Epoch 12/119
# ----------
# train Loss: 0.3236 Acc: 0.8865
# val Loss: 0.4596 Acc: 0.8562
#
# Epoch 13/119
# ----------
# train Loss: 0.3139 Acc: 0.8916
# val Loss: 0.3223 Acc: 0.8953
#
# Epoch 14/119
# ----------
# train Loss: 0.2925 Acc: 0.8980
# val Loss: 0.3342 Acc: 0.8902
#
# Epoch 15/119
# ----------
# train Loss: 0.2901 Acc: 0.9018
# val Loss: 0.3080 Acc: 0.9126
#
# Epoch 16/119
# ----------
# train Loss: 0.2942 Acc: 0.9012
# val Loss: 0.3248 Acc: 0.8982
#
# Epoch 17/119
# ----------
# train Loss: 0.2965 Acc: 0.9000
# val Loss: 0.4863 Acc: 0.8482
#
# Epoch 18/119
# ----------
# train Loss: 0.2964 Acc: 0.8970
# val Loss: 0.3289 Acc: 0.8988
#
# Epoch 19/119
# ----------
# train Loss: 0.2881 Acc: 0.9028
# val Loss: 0.3520 Acc: 0.8902
#
# Epoch 20/119
# ----------
# train Loss: 0.2899 Acc: 0.9016
# val Loss: 0.3202 Acc: 0.9057
#
# Epoch 21/119
# ----------
# train Loss: 0.2901 Acc: 0.9016
# val Loss: 0.3118 Acc: 0.9051
#
# Epoch 22/119
# ----------
# train Loss: 0.2802 Acc: 0.9061
# val Loss: 0.5230 Acc: 0.8493
#
# Epoch 23/119
# ----------
# train Loss: 0.2881 Acc: 0.9000
# val Loss: 0.3356 Acc: 0.9063
#
# Epoch 24/119
# ----------
# train Loss: 0.2956 Acc: 0.8967
# val Loss: 0.3078 Acc: 0.9097
#
# Epoch 25/119
# ----------
# train Loss: 0.2817 Acc: 0.9035
# val Loss: 0.3828 Acc: 0.8838
#
# Epoch 26/119
# ----------
# train Loss: 0.2865 Acc: 0.9021
# val Loss: 0.3117 Acc: 0.9040
#
# Epoch 27/119
# ----------
# train Loss: 0.2873 Acc: 0.9038
# val Loss: 0.4017 Acc: 0.8804
#
# Epoch 28/119
# ----------
# train Loss: 0.2963 Acc: 0.8985
# val Loss: 0.2982 Acc: 0.9074
#
# Epoch 29/119
# ----------
# train Loss: 0.2963 Acc: 0.8983
# val Loss: 0.4858 Acc: 0.8568
#
# Epoch 30/119
# ----------
# train Loss: 0.2887 Acc: 0.9028
# val Loss: 0.3388 Acc: 0.8936
#
# Epoch 31/119
# ----------
# train Loss: 0.2847 Acc: 0.9034
# val Loss: 0.3774 Acc: 0.8729
#
# Epoch 32/119
# ----------
# train Loss: 0.2830 Acc: 0.9023
# val Loss: 0.3167 Acc: 0.9063
#
# Epoch 33/119
# ----------
# train Loss: 0.2841 Acc: 0.9041
# val Loss: 0.3148 Acc: 0.9051
#
# Epoch 34/119
# ----------
# train Loss: 0.3018 Acc: 0.8949
# val Loss: 0.2675 Acc: 0.9143
#
# Epoch 35/119
# ----------
# train Loss: 0.3001 Acc: 0.8993
# val Loss: 0.2675 Acc: 0.9183
#
# Epoch 36/119
# ----------
# train Loss: 0.2875 Acc: 0.9013
# val Loss: 0.3278 Acc: 0.8919
#
# Epoch 37/119
# ----------
# train Loss: 0.2995 Acc: 0.8985
# val Loss: 0.2994 Acc: 0.9051
#
# Epoch 38/119
# ----------
# train Loss: 0.2781 Acc: 0.9049
# val Loss: 0.3072 Acc: 0.9080
#
# Epoch 39/119
# ----------
# train Loss: 0.2864 Acc: 0.9031
# val Loss: 0.3730 Acc: 0.8775
#
# Epoch 40/119
# ----------
# train Loss: 0.2832 Acc: 0.9048
# val Loss: 0.3651 Acc: 0.8861
#
# Epoch 41/119
# ----------
# train Loss: 0.2891 Acc: 0.8954
# val Loss: 0.3187 Acc: 0.8965
#
# Epoch 42/119
# ----------
# train Loss: 0.2925 Acc: 0.8957
# val Loss: 0.3735 Acc: 0.8936
#
# Epoch 43/119
# ----------
# train Loss: 0.2812 Acc: 0.9038
# val Loss: 0.3066 Acc: 0.9028
#
# Epoch 44/119
# ----------
# train Loss: 0.2943 Acc: 0.9012
# val Loss: 0.3491 Acc: 0.8930
#
# Epoch 45/119
# ----------
# train Loss: 0.2843 Acc: 0.9015
# val Loss: 0.2977 Acc: 0.9097
#
# Epoch 46/119
# ----------
# train Loss: 0.2924 Acc: 0.8975
# val Loss: 0.3714 Acc: 0.8873
#
# Epoch 47/119
# ----------
# train Loss: 0.2915 Acc: 0.9039
# val Loss: 0.2947 Acc: 0.9103
#
# Epoch 48/119
# ----------
# train Loss: 0.2849 Acc: 0.9062
# val Loss: 0.2926 Acc: 0.9074
#
# Epoch 49/119
# ----------
# train Loss: 0.2928 Acc: 0.9000
# val Loss: 0.3247 Acc: 0.9080
#
# Epoch 50/119
# ----------
# train Loss: 0.2999 Acc: 0.9006
# val Loss: 0.3001 Acc: 0.9114
#
# Epoch 51/119
# ----------
# train Loss: 0.2897 Acc: 0.9002
# val Loss: 0.3272 Acc: 0.8994
#
# Epoch 52/119
# ----------
# train Loss: 0.2833 Acc: 0.9016
# val Loss: 0.3081 Acc: 0.9040
#
# Epoch 53/119
# ----------
# train Loss: 0.2821 Acc: 0.9049
# val Loss: 0.3209 Acc: 0.9034
#
# Epoch 54/119
# ----------
# train Loss: 0.2866 Acc: 0.9012
# val Loss: 0.5666 Acc: 0.8390
#
# Epoch 55/119
# ----------
# train Loss: 0.2976 Acc: 0.8970
# val Loss: 0.4047 Acc: 0.8660
#
# Epoch 56/119
# ----------
# train Loss: 0.2758 Acc: 0.9058
# val Loss: 0.4473 Acc: 0.8672
#
# Epoch 57/119
# ----------
# train Loss: 0.2890 Acc: 0.9000
# val Loss: 0.2892 Acc: 0.9126
#
# Epoch 58/119
# ----------
# train Loss: 0.3009 Acc: 0.8995
# val Loss: 0.3226 Acc: 0.8999
#
# Epoch 59/119
# ----------
# train Loss: 0.2843 Acc: 0.9028
# val Loss: 0.3220 Acc: 0.9022
#
# Epoch 60/119
# ----------
# train Loss: 0.2934 Acc: 0.8992
# val Loss: 0.3466 Acc: 0.8976
#
# Epoch 61/119
# ----------
# train Loss: 0.2958 Acc: 0.8957
# val Loss: 0.2968 Acc: 0.9114
#
# Epoch 62/119
# ----------
# train Loss: 0.2836 Acc: 0.9046
# val Loss: 0.3246 Acc: 0.9028
#
# Epoch 63/119
# ----------
# train Loss: 0.2722 Acc: 0.9101
# val Loss: 0.3109 Acc: 0.9080
#
# Epoch 64/119
# ----------
# train Loss: 0.2919 Acc: 0.9028
# val Loss: 0.4203 Acc: 0.8637
#
# Epoch 65/119
# ----------
# train Loss: 0.2921 Acc: 0.9026
# val Loss: 0.3313 Acc: 0.8907
#
# Epoch 66/119
# ----------
# train Loss: 0.2774 Acc: 0.9057
# val Loss: 0.3386 Acc: 0.9005
#
# Epoch 67/119
# ----------
# train Loss: 0.2830 Acc: 0.9039
# val Loss: 0.3184 Acc: 0.8982
#
# Epoch 68/119
# ----------
# train Loss: 0.2868 Acc: 0.9038
# val Loss: 0.3107 Acc: 0.9109
#
# Epoch 69/119
# ----------
# train Loss: 0.2885 Acc: 0.8980
# val Loss: 0.5361 Acc: 0.8430
#
# Epoch 70/119
# ----------
# train Loss: 0.2897 Acc: 0.9018
# val Loss: 0.3348 Acc: 0.8925
#
# Epoch 71/119
# ----------
# train Loss: 0.2814 Acc: 0.9048
# val Loss: 0.2924 Acc: 0.9086
#
# Epoch 72/119
# ----------
# train Loss: 0.3033 Acc: 0.8996
# val Loss: 0.3377 Acc: 0.9005
#
# Epoch 73/119
# ----------
# train Loss: 0.2856 Acc: 0.9012
# val Loss: 0.4310 Acc: 0.8603
#
# Epoch 74/119
# ----------
# train Loss: 0.2882 Acc: 0.8999
# val Loss: 0.3705 Acc: 0.8873
#
# Epoch 75/119
# ----------
# train Loss: 0.2857 Acc: 0.9046
# val Loss: 0.3042 Acc: 0.8971
#
# Epoch 76/119
# ----------
# train Loss: 0.2859 Acc: 0.9013
# val Loss: 0.3377 Acc: 0.8942
#
# Epoch 77/119
# ----------
# train Loss: 0.2987 Acc: 0.8957
# val Loss: 0.2702 Acc: 0.9126
#
# Epoch 78/119
# ----------
# train Loss: 0.2885 Acc: 0.9026
# val Loss: 0.2990 Acc: 0.9114
#
# Epoch 79/119
# ----------
# train Loss: 0.2902 Acc: 0.9008
# val Loss: 0.3071 Acc: 0.9074
#
# Epoch 80/119
# ----------
# train Loss: 0.2953 Acc: 0.8995
# val Loss: 0.3090 Acc: 0.9022
#
# Epoch 81/119
# ----------
# train Loss: 0.2809 Acc: 0.9046
# val Loss: 0.4300 Acc: 0.8695
#
# Epoch 82/119
# ----------
# train Loss: 0.2822 Acc: 0.9025
# val Loss: 0.3065 Acc: 0.9063
#
# Epoch 83/119
# ----------
# train Loss: 0.2845 Acc: 0.9019
# val Loss: 0.3765 Acc: 0.8775
#
# Epoch 84/119
# ----------
# train Loss: 0.2821 Acc: 0.9029
# val Loss: 0.3243 Acc: 0.8994
#
# Epoch 85/119
# ----------
# train Loss: 0.2866 Acc: 0.9010
# val Loss: 0.3201 Acc: 0.8999
#
# Epoch 86/119
# ----------
# train Loss: 0.2834 Acc: 0.9091
# val Loss: 0.3351 Acc: 0.8942
#
# Epoch 87/119
# ----------
# train Loss: 0.2918 Acc: 0.8956
# val Loss: 0.2983 Acc: 0.9063
#
# Epoch 88/119
# ----------
# train Loss: 0.2874 Acc: 0.8996
# val Loss: 0.3292 Acc: 0.9017
#
# Epoch 89/119
# ----------
# train Loss: 0.2951 Acc: 0.8976
# val Loss: 0.3251 Acc: 0.9011
#
# Epoch 90/119
# ----------
# train Loss: 0.2877 Acc: 0.9016
# val Loss: 0.5623 Acc: 0.8275
#
# Epoch 91/119
# ----------
# train Loss: 0.2975 Acc: 0.8996
# val Loss: 0.2861 Acc: 0.8999
#
# Epoch 92/119
# ----------
# train Loss: 0.2798 Acc: 0.9048
# val Loss: 0.2901 Acc: 0.9074
#
# Epoch 93/119
# ----------
# train Loss: 0.2886 Acc: 0.8995
# val Loss: 0.3271 Acc: 0.9017
#
# Epoch 94/119
# ----------
# train Loss: 0.2937 Acc: 0.9026
# val Loss: 0.2971 Acc: 0.9103
#
# Epoch 95/119
# ----------
# train Loss: 0.2890 Acc: 0.8998
# val Loss: 0.3269 Acc: 0.9022
#
# Epoch 96/119
# ----------
# train Loss: 0.2838 Acc: 0.9061
# val Loss: 0.3094 Acc: 0.9051
#
# Epoch 97/119
# ----------
# train Loss: 0.2825 Acc: 0.9026
# val Loss: 0.3097 Acc: 0.9068
#
# Epoch 98/119
# ----------
# train Loss: 0.2909 Acc: 0.9012
# val Loss: 0.3354 Acc: 0.8942
#
# Epoch 99/119
# ----------
# train Loss: 0.2769 Acc: 0.9045
# val Loss: 0.3862 Acc: 0.8850
#
# Epoch 100/119
# ----------
# train Loss: 0.2922 Acc: 0.8987
# val Loss: 0.2931 Acc: 0.9086
#
# Epoch 101/119
# ----------
# train Loss: 0.2752 Acc: 0.9038
# val Loss: 0.3576 Acc: 0.8936
#
# Epoch 102/119
# ----------
# train Loss: 0.2927 Acc: 0.9003
# val Loss: 0.3109 Acc: 0.8999
#
# Epoch 103/119
# ----------
# train Loss: 0.2897 Acc: 0.8998
# val Loss: 0.5100 Acc: 0.8373
#
# Epoch 104/119
# ----------
# train Loss: 0.2866 Acc: 0.9012
# val Loss: 0.3400 Acc: 0.8890
#
# Epoch 105/119
# ----------
# train Loss: 0.2833 Acc: 0.9028
# val Loss: 0.3467 Acc: 0.8982
#
# Epoch 106/119
# ----------
# train Loss: 0.2750 Acc: 0.9081
# val Loss: 0.2908 Acc: 0.9068
#
# Epoch 107/119
# ----------
# train Loss: 0.2955 Acc: 0.8979
# val Loss: 0.4173 Acc: 0.8626
#
# Epoch 108/119
# ----------
# train Loss: 0.2777 Acc: 0.9013
# val Loss: 0.3059 Acc: 0.9097
#
# Epoch 109/119
# ----------
# train Loss: 0.2942 Acc: 0.8986
# val Loss: 0.3188 Acc: 0.9034
#
# Epoch 110/119
# ----------
# train Loss: 0.2889 Acc: 0.8995
# val Loss: 0.3673 Acc: 0.8844
#
# Epoch 111/119
# ----------
# train Loss: 0.2926 Acc: 0.9008
# val Loss: 0.3289 Acc: 0.8965
#
# Epoch 112/119
# ----------
# train Loss: 0.2872 Acc: 0.9013
# val Loss: 0.3333 Acc: 0.9028
#
# Epoch 113/119
# ----------
# train Loss: 0.2961 Acc: 0.9016
# val Loss: 0.3633 Acc: 0.8896
#
# Epoch 114/119
# ----------
# train Loss: 0.2866 Acc: 0.9010
# val Loss: 0.4811 Acc: 0.8551
#
# Epoch 115/119
# ----------
# train Loss: 0.2924 Acc: 0.9025
# val Loss: 0.3581 Acc: 0.8971
#
# Epoch 116/119
# ----------
# train Loss: 0.2817 Acc: 0.9075
# val Loss: 0.3302 Acc: 0.9034
#
# Epoch 117/119
# ----------
# train Loss: 0.2908 Acc: 0.9000
# val Loss: 0.3592 Acc: 0.8815
#
# Epoch 118/119
# ----------
# train Loss: 0.2792 Acc: 0.9067
# val Loss: 0.3097 Acc: 0.9045
#
# Epoch 119/119
# ----------
# train Loss: 0.2853 Acc: 0.9021
# val Loss: 0.2966 Acc: 0.9097
#
# Training complete in 175m 55s
# Best val Acc: 0.918344

# %%
torch.save(model_ft.state_dict(), "C:/Users/user/Documents/experimentefficientnetb001sgdrgb.pt")

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_model(model_ft)

# %%
correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        # calculate outputs by running images through the network
        outputs = model_ft(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of the network on the big15 test images: {100 * correct // total} %')
# Out:
# Accuracy of the network on the big15 test images: 89 %

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
predicted_labels = []
true_labels = []
label_names = ['Gatak', 'Kelihos_ver1', 'Kelihos_ver3', 'Lollipop', 'Obfuscator.ACY', 'Ramnit', 'Simda', 'Tracur', 'Vundo']
model_ft.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model_ft(images)
        _,predicted = torch.max(outputs, 1)
        predicted_labels.extend(predicted.cpu().numpy())
        true_labels.extend(labels.cpu().numpy())
predicted_labels = np.array(predicted_labels)
true_labels = np.array(true_labels)
confusion = confusion_matrix(true_labels, predicted_labels)
normalized_matrix = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
sns.set()
plt.figure(figsize=(10, 8))
sns.heatmap(normalized_matrix, annot=True, cmap="Blues", xticklabels=label_names, yticklabels=label_names)
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
# Out:
# Text(92.109375, 0.5, 'True labels')
